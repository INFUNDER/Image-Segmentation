# %%
import cv2
from skimage.filters.rank import entropy
from skimage.morphology import disk
import pandas as pd
from skimage import io
from scipy import ndimage as nd
from skimage.filters import sobel

# %%
img = cv2.imread('images/7.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img2 = img.reshape(-1)
df = pd.DataFrame()
df['Original Image'] = img2

# %%
io.imshow(img)

# %%
entropy_img = entropy(img, disk(1))
io.imshow(entropy_img)
entropy1 = entropy_img.reshape(-1)
df['Entropy'] = entropy1
# Out:
# /Users/ronitmittal/anaconda3/lib/python3.11/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
gaussian_img = nd.gaussian_filter(img, sigma=3)
io.imshow(gaussian_img)
gaussian_img1 = gaussian_img.reshape(-1)
df['Gaussian s3'] = gaussian_img1

# %%
sobel_img = sobel(img)
io.imshow(sobel_img)
sobel1 = sobel_img.reshape(-1)
df['Sobel'] = sobel1
# Out:
# /Users/ronitmittal/anaconda3/lib/python3.11/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
df.head(10)
# Out:
#    Original Image   Entropy  Gaussian s3     Sobel
# 0             158  1.584963          159  0.007904
# 1             159  1.500000          160  0.013335
# 2             162  1.500000          160  0.010422
# 3             163  1.000000          160  0.002941
# 4             163  0.811278          160  0.002773
# 5             163  0.811278          160  0.006201
# 6             163  1.500000          160  0.011433
# 7             165  2.000000          160  0.011433
# 8             161  2.000000          160  0.007843
# 9             162  1.500000          160  0.011967
