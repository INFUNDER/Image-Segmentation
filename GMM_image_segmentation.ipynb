# %%
import numpy as np 
import cv2
from skimage import io

# %%
img = cv2.imread('images/grain.jpg')

# %%
io.imshow(img)

# %%
img2 = img.reshape(-1,3)

# %%
img2.shape
# Out:
# (712968, 3)

# %%
from sklearn.mixture import GaussianMixture as GMM

# %%
gmm_model = GMM(n_components=2, covariance_type='tied').fit(img2)  
gmm_labels = gmm_model.predict(img2)

# %%
original_shape = img.shape
segmented = gmm_labels.reshape(original_shape[0], original_shape[1])
io.imshow(segmented)
# Out:
# /Users/ronitmittal/anaconda3/lib/python3.11/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
